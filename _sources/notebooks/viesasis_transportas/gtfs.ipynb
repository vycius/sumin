# %% [markdown]
# # GTFS
#
# ## GTFS VINTRA

# %%
import numpy as np
import pandas as pd
from itables import init_notebook_mode
import os
import subprocess

init_notebook_mode(all_interactive=True)

# %%
working_directory = f'{os.getcwd()}/../../data/gtfs/vintra/'
gtfs_files_directory = f'{working_directory}/gtfs-files/'

gtfs_file_stats_df = pd.DataFrame()

for file in sorted(os.listdir(gtfs_files_directory)):
    if file.endswith('.zip'):
        filename, _, _ = file.partition('.zip')

        p = subprocess.Popen([
            f'java -jar gtfs-validator-301.jar -i gtfs-files/{file} -o reports -v {filename}_report.json -e {filename}_system_errors.json -n -c lt'],
            cwd=working_directory, shell=True, stdout=subprocess.PIPE,
            stderr=subprocess.PIPE)
        out, err = p.communicate(timeout=60)
        errcode = p.returncode

        _, _, gtfs_files_txt = out.decode("utf-8").partition('seconds\n')
        gtfs_files = gtfs_files_txt.splitlines()

        gtfs_files_dict = {'failas': filename}
        for gtfs_file_rep in gtfs_files:
            gtfs_file, c = gtfs_file_rep.split('\t')
            gtfs_files_dict[gtfs_file] = c if c != 'MISSING_FILE' else None

        gtfs_file_stats_df = gtfs_file_stats_df.append(gtfs_files_dict, ignore_index=True, )

gtfs_file_stats_df = gtfs_file_stats_df.reindex(
    columns=[
        'failas',
        'agency.txt',
        'calendar.txt',
        'calendar_dates.txt',
        'routes.txt',
        'shapes.txt',
        'stop_times.txt',
        'stops.txt',
        'trips.txt',
        'fare_attributes.txt',
        'fare_rules.txt',
        'attributions.txt',
        'feed_info.txt',
        'frequencies.txt',
        'levels.txt',
        'pathways.txt',
        'transfers.txt',
        'translations.txt'
    ]
).set_index('failas')


gtfs_file_stats_df[
    [
        'agency.txt',
        'calendar.txt',
        'calendar_dates.txt',
        'routes.txt',
        'shapes.txt',
        'stop_times.txt',
        'stops.txt',
        'trips.txt',
        'fare_attributes.txt',
        'fare_rules.txt',
    ]
] = gtfs_file_stats_df[
    [
        'agency.txt',
        'calendar.txt',
        'calendar_dates.txt',
        'routes.txt',
        'shapes.txt',
        'stop_times.txt',
        'stops.txt',
        'trips.txt',
        'fare_attributes.txt',
        'fare_rules.txt',
    ]
].fillna('❌')

gtfs_file_stats_df.fillna('⚠️', inplace=True)
gtfs_file_stats_df.style.set_sticky(axis="index")

gtfs_file_stats_df
# Out:
#                agency.txt calendar.txt calendar_dates.txt routes.txt  \
# failas
# AlytausM                1           36                109         16
# AlytausR                1            7                 77         25
# AnyksciuR               1           33                  ❌         32
# Birstono                ❌            ❌                  ❌          ❌
# BirzuR                  1           40               3826          ❌
# ...                   ...          ...                ...        ...
# akmene                  1           22                909         47
# birstono-gtfs           ❌            ❌                  ❌          ❌
# google_transit          5          176               2856         51
# gtfs_all               68         4125              33078       1923
# neringa                 1            2                  ❌          1
#
#                shapes.txt stop_times.txt stops.txt trips.txt  \
# failas
# AlytausM            10780           5744       190       297
# AlytausR            61971           2885       434       171
# AnyksciuR           54145           2627       365       188
# Birstono                ❌              ❌         ❌         ❌
# BirzuR                  ❌              ❌         ❌         ❌
# ...                   ...            ...       ...       ...
# akmene              80820           1322       199       108
# birstono-gtfs           ❌              ❌         ❌         ❌
# google_transit     115909           2940       664       188
# gtfs_all          2393862          61318      5959      3902
# neringa              8449            329        23        28
#
#                fare_attributes.txt fare_rules.txt attributions.txt  \
# failas
# AlytausM                         ❌              ❌               ⚠️
# AlytausR                         ❌              ❌               ⚠️
# AnyksciuR                        ❌              ❌               ⚠️
# Birstono                         ❌              ❌               ⚠️
# BirzuR                           ❌              ❌               ⚠️
# ...                            ...            ...              ...
# akmene                           ❌              ❌               ⚠️
# birstono-gtfs                    ❌              ❌               ⚠️
# google_transit                   ❌              ❌               ⚠️
# gtfs_all                    283321         283321               ⚠️
# neringa                          ❌              ❌               ⚠️
#
#                feed_info.txt frequencies.txt levels.txt pathways.txt  \
# failas
# AlytausM                  ⚠️              ⚠️         ⚠️           ⚠️
# AlytausR                  ⚠️              ⚠️         ⚠️           ⚠️
# AnyksciuR                 ⚠️              ⚠️         ⚠️           ⚠️
# Birstono                  ⚠️              ⚠️         ⚠️           ⚠️
# BirzuR                    ⚠️              ⚠️         ⚠️           ⚠️
# ...                      ...             ...        ...          ...
# akmene                    ⚠️              ⚠️         ⚠️           ⚠️
# birstono-gtfs             ⚠️              ⚠️         ⚠️           ⚠️
# google_transit            ⚠️              ⚠️         ⚠️           ⚠️
# gtfs_all                  ⚠️              ⚠️         ⚠️           ⚠️
# neringa                   ⚠️              ⚠️         ⚠️           ⚠️
#
#                transfers.txt translations.txt
# failas
# AlytausM                  ⚠️               ⚠️
# AlytausR                  ⚠️               ⚠️
# AnyksciuR                 ⚠️               ⚠️
# Birstono                  ⚠️               ⚠️
# BirzuR                    ⚠️               ⚠️
# ...                      ...              ...
# akmene                    ⚠️               ⚠️
# birstono-gtfs             ⚠️               ⚠️
# google_transit            ⚠️               ⚠️
# gtfs_all                  ⚠️               ⚠️
# neringa                   ⚠️               ⚠️
#
# [62 rows x 17 columns]

# %%
import json

reports_dir = f'{working_directory}/reports/'

gtfs_notices_df = pd.DataFrame()


for file in sorted(os.listdir(reports_dir)):
    if file.endswith('report.json'):
        gtfs_filename, _, _ = file.partition('_report.json')

        with open(os.path.join(reports_dir, file)) as fp:
                data = json.load(fp)

                for notice in data['notices']:
                    gtfs_notices_df = gtfs_notices_df.append({
                        'failas': gtfs_filename,
                        'klaida': notice['code'],
                        'sunkumas': notice['severity'],
                        'viso': notice['totalNotices'],
                    }, ignore_index=True, )


gtfs_notices_df['viso'] = pd.to_numeric(gtfs_notices_df['viso'], downcast='integer')

gtfs_notices_df[gtfs_notices_df['sunkumas'] == 'ERROR']
# Out:
#              failas                                  klaida sunkumas   viso
# 5         AnyksciuR   equal_shape_distance_diff_coordinates    ERROR      1
# 9          Birstono                   missing_required_file    ERROR      5
# 11           BirzuR                   missing_required_file    ERROR      4
# 13      Druskininku                   missing_required_file    ERROR      4
# 17       IgnalinosR   equal_shape_distance_diff_coordinates    ERROR      5
# 21         JonavosR   equal_shape_distance_diff_coordinates    ERROR      1
# 26        JoniskioR   equal_shape_distance_diff_coordinates    ERROR      1
# 30        JurbarkoR   equal_shape_distance_diff_coordinates    ERROR      2
# 35       Kalvarijos                   missing_required_file    ERROR      4
# 37           KaunoM                   missing_required_file    ERROR      4
# 41       Kazlurudos                   missing_required_file    ERROR      4
# 43        KedainiuR   equal_shape_distance_diff_coordinates    ERROR     17
# 49          KelmesR   equal_shape_distance_diff_coordinates    ERROR  13417
# 61       KlaipedosR   equal_shape_distance_diff_coordinates    ERROR  13417
# 72        KupiskioR                   missing_required_file    ERROR      4
# 74            LTSAR   equal_shape_distance_diff_coordinates    ERROR  10317
# 82         LazdijuR                   missing_required_file    ERROR      4
# 97        PakruojoR                   missing_required_file    ERROR      4
# 101      PanevezioM                   missing_required_file    ERROR      4
# 103      PanevezioR                   missing_required_file    ERROR      4
# 105       PasvalioR   equal_shape_distance_diff_coordinates    ERROR  13416
# 116         PrienuR                   missing_required_file    ERROR      4
# 118    RadviliskioR   equal_shape_distance_diff_coordinates    ERROR      1
# 122       RaseiniuR   equal_shape_distance_diff_coordinates    ERROR      1
# 127       RokiskioR   equal_shape_distance_diff_coordinates    ERROR      1
# 141        SilutesR   equal_shape_distance_diff_coordinates    ERROR      7
# 144         SkuodoR   equal_shape_distance_diff_coordinates    ERROR      1
# 158          TrakuR   equal_shape_distance_diff_coordinates    ERROR      1
# 164       UkmergesR   equal_shape_distance_diff_coordinates    ERROR      1
# 169         UtenosR   equal_shape_distance_diff_coordinates    ERROR      1
# 173        VarenosR   equal_shape_distance_diff_coordinates    ERROR      1
# 190         ZarasuR   equal_shape_distance_diff_coordinates    ERROR      1
# 198   birstono-gtfs                   missing_required_file    ERROR      5
# 200  google_transit   equal_shape_distance_diff_coordinates    ERROR      6
# 205        gtfs_all  decreasing_or_equal_stop_time_distance    ERROR      8
# 206        gtfs_all      duplicate_fare_rule_zone_id_fields    ERROR   2368
# 208        gtfs_all   equal_shape_distance_diff_coordinates    ERROR  10327

# %%
import numpy as np
gtfs_errors_df = gtfs_notices_df[gtfs_notices_df['sunkumas'] == 'ERROR'].drop(columns=['sunkumas']).pivot_table(index='failas', columns='klaida', values='viso')

float_col = gtfs_errors_df.select_dtypes(include=['float64'])

for col in float_col.columns.values:
    gtfs_errors_df[col] = gtfs_errors_df[col].astype('int64', errors='ignore')

gtfs_errors_df = gtfs_errors_df.fillna('')

gtfs_errors_df = gtfs_errors_df.style.apply(lambda x: ["background: orange" if v != '' else '' for v in x], axis = 1)

gtfs_errors_df
# Out:
# <style type="text/css">
# #T_6ad8c_row0_col2, #T_6ad8c_row1_col3, #T_6ad8c_row2_col3, #T_6ad8c_row3_col3, #T_6ad8c_row4_col2, #T_6ad8c_row5_col2, #T_6ad8c_row6_col2, #T_6ad8c_row7_col2, #T_6ad8c_row8_col3, #T_6ad8c_row9_col3, #T_6ad8c_row10_col3, #T_6ad8c_row11_col2, #T_6ad8c_row12_col2, #T_6ad8c_row13_col2, #T_6ad8c_row14_col3, #T_6ad8c_row15_col2, #T_6ad8c_row16_col3, #T_6ad8c_row17_col3, #T_6ad8c_row18_col3, #T_6ad8c_row19_col3, #T_6ad8c_row20_col2, #T_6ad8c_row21_col3, #T_6ad8c_row22_col2, #T_6ad8c_row23_col2, #T_6ad8c_row24_col2, #T_6ad8c_row25_col2, #T_6ad8c_row26_col2, #T_6ad8c_row27_col2, #T_6ad8c_row28_col2, #T_6ad8c_row29_col2, #T_6ad8c_row30_col2, #T_6ad8c_row31_col2, #T_6ad8c_row32_col3, #T_6ad8c_row33_col2, #T_6ad8c_row34_col0, #T_6ad8c_row34_col1, #T_6ad8c_row34_col2 {
#   background: orange;
# }
# </style>
# <table id="T_6ad8c_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >klaida</th>
#       <th class="col_heading level0 col0" >decreasing_or_equal_stop_time_distance</th>
#       <th class="col_heading level0 col1" >duplicate_fare_rule_zone_id_fields</th>
#       <th class="col_heading level0 col2" >equal_shape_distance_diff_coordinates</th>
#       <th class="col_heading level0 col3" >missing_required_file</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >failas</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ad8c_level0_row0" class="row_heading level0 row0" >AnyksciuR</th>
#       <td id="T_6ad8c_row0_col0" class="data row0 col0" ></td>
#       <td id="T_6ad8c_row0_col1" class="data row0 col1" ></td>
#       <td id="T_6ad8c_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_6ad8c_row0_col3" class="data row0 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_6ad8c_level0_row1" class="row_heading level0 row1" >Birstono</th>
#       <td id="T_6ad8c_row1_col0" class="data row1 col0" ></td>
#       <td id="T_6ad8c_row1_col1" class="data row1 col1" ></td>
#       <td id="T_6ad8c_row1_col2" class="data row1 col2" ></td>
#       <td id="T_6ad8c_row1_col3" class="data row1 col3" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ad8c_level0_row2" class="row_heading level0 row2" >BirzuR</th>
#       <td id="T_6ad8c_row2_col0" class="data row2 col0" ></td>
#       <td id="T_6ad8c_row2_col1" class="data row2 col1" ></td>
#       <td id="T_6ad8c_row2_col2" class="data row2 col2" ></td>
#       <td id="T_6ad8c_row2_col3" class="data row2 col3" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ad8c_level0_row3" class="row_heading level0 row3" >Druskininku</th>
#       <td id="T_6ad8c_row3_col0" class="data row3 col0" ></td>
#       <td id="T_6ad8c_row3_col1" class="data row3 col1" ></td>
#       <td id="T_6ad8c_row3_col2" class="data row3 col2" ></td>
#       <td id="T_6ad8c_row3_col3" class="data row3 col3" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ad8c_level0_row4" class="row_heading level0 row4" >IgnalinosR</th>
#       <td id="T_6ad8c_row4_col0" class="data row4 col0" ></td>
#       <td id="T_6ad8c_row4_col1" class="data row4 col1" ></td>
#       <td id="T_6ad8c_row4_col2" class="data row4 col2" >5.000000</td>
#       <td id="T_6ad8c_row4_col3" class="data row4 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_6ad8c_level0_row5" class="row_heading level0 row5" >JonavosR</th>
#       <td id="T_6ad8c_row5_col0" class="data row5 col0" ></td>
#       <td id="T_6ad8c_row5_col1" class="data row5 col1" ></td>
#       <td id="T_6ad8c_row5_col2" class="data row5 col2" >1.000000</td>
#       <td id="T_6ad8c_row5_col3" class="data row5 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_6ad8c_level0_row6" class="row_heading level0 row6" >JoniskioR</th>
#       <td id="T_6ad8c_row6_col0" class="data row6 col0" ></td>
#       <td id="T_6ad8c_row6_col1" class="data row6 col1" ></td>
#       <td id="T_6ad8c_row6_col2" class="data row6 col2" >1.000000</td>
#       <td id="T_6ad8c_row6_col3" class="data row6 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_6ad8c_level0_row7" class="row_heading level0 row7" >JurbarkoR</th>
#       <td id="T_6ad8c_row7_col0" class="data row7 col0" ></td>
#       <td id="T_6ad8c_row7_col1" class="data row7 col1" ></td>
#       <td id="T_6ad8c_row7_col2" class="data row7 col2" >2.000000</td>
#       <td id="T_6ad8c_row7_col3" class="data row7 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_6ad8c_level0_row8" class="row_heading level0 row8" >Kalvarijos</th>
#       <td id="T_6ad8c_row8_col0" class="data row8 col0" ></td>
#       <td id="T_6ad8c_row8_col1" class="data row8 col1" ></td>
#       <td id="T_6ad8c_row8_col2" class="data row8 col2" ></td>
#       <td id="T_6ad8c_row8_col3" class="data row8 col3" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ad8c_level0_row9" class="row_heading level0 row9" >KaunoM</th>
#       <td id="T_6ad8c_row9_col0" class="data row9 col0" ></td>
#       <td id="T_6ad8c_row9_col1" class="data row9 col1" ></td>
#       <td id="T_6ad8c_row9_col2" class="data row9 col2" ></td>
#       <td id="T_6ad8c_row9_col3" class="data row9 col3" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ad8c_level0_row10" class="row_heading level0 row10" >Kazlurudos</th>
#       <td id="T_6ad8c_row10_col0" class="data row10 col0" ></td>
#       <td id="T_6ad8c_row10_col1" class="data row10 col1" ></td>
#       <td id="T_6ad8c_row10_col2" class="data row10 col2" ></td>
#       <td id="T_6ad8c_row10_col3" class="data row10 col3" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ad8c_level0_row11" class="row_heading level0 row11" >KedainiuR</th>
#       <td id="T_6ad8c_row11_col0" class="data row11 col0" ></td>
#       <td id="T_6ad8c_row11_col1" class="data row11 col1" ></td>
#       <td id="T_6ad8c_row11_col2" class="data row11 col2" >17.000000</td>
#       <td id="T_6ad8c_row11_col3" class="data row11 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_6ad8c_level0_row12" class="row_heading level0 row12" >KelmesR</th>
#       <td id="T_6ad8c_row12_col0" class="data row12 col0" ></td>
#       <td id="T_6ad8c_row12_col1" class="data row12 col1" ></td>
#       <td id="T_6ad8c_row12_col2" class="data row12 col2" >13417.000000</td>
#       <td id="T_6ad8c_row12_col3" class="data row12 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_6ad8c_level0_row13" class="row_heading level0 row13" >KlaipedosR</th>
#       <td id="T_6ad8c_row13_col0" class="data row13 col0" ></td>
#       <td id="T_6ad8c_row13_col1" class="data row13 col1" ></td>
#       <td id="T_6ad8c_row13_col2" class="data row13 col2" >13417.000000</td>
#       <td id="T_6ad8c_row13_col3" class="data row13 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_6ad8c_level0_row14" class="row_heading level0 row14" >KupiskioR</th>
#       <td id="T_6ad8c_row14_col0" class="data row14 col0" ></td>
#       <td id="T_6ad8c_row14_col1" class="data row14 col1" ></td>
#       <td id="T_6ad8c_row14_col2" class="data row14 col2" ></td>
#       <td id="T_6ad8c_row14_col3" class="data row14 col3" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ad8c_level0_row15" class="row_heading level0 row15" >LTSAR</th>
#       <td id="T_6ad8c_row15_col0" class="data row15 col0" ></td>
#       <td id="T_6ad8c_row15_col1" class="data row15 col1" ></td>
#       <td id="T_6ad8c_row15_col2" class="data row15 col2" >10317.000000</td>
#       <td id="T_6ad8c_row15_col3" class="data row15 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_6ad8c_level0_row16" class="row_heading level0 row16" >LazdijuR</th>
#       <td id="T_6ad8c_row16_col0" class="data row16 col0" ></td>
#       <td id="T_6ad8c_row16_col1" class="data row16 col1" ></td>
#       <td id="T_6ad8c_row16_col2" class="data row16 col2" ></td>
#       <td id="T_6ad8c_row16_col3" class="data row16 col3" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ad8c_level0_row17" class="row_heading level0 row17" >PakruojoR</th>
#       <td id="T_6ad8c_row17_col0" class="data row17 col0" ></td>
#       <td id="T_6ad8c_row17_col1" class="data row17 col1" ></td>
#       <td id="T_6ad8c_row17_col2" class=
